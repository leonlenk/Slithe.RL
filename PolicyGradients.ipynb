# %%
import gym_env.RewardWrapper
import model.Policy

from gymnasium.wrappers import RecordVideo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import gym_env.RewardWrapper
#       2 import model.Policy
#
# File ~/ACM_AI/SlitheRL/gym_env.py:1
# ----> 1 # Define a wrapper for Gym env to add survival rewards
#       2 class RewardWrapper(gym.Wrapper):
#       3     def __init__(self, env, survival_reward=0.01):
#
# ModuleNotFoundError: No module named 'gymnasium'

# %%
# Get the current timestamp
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# Create the Gymnasium environment
env = gym.make("ALE/Surround-v5", render_mode="rgb_array", mode=2, difficulty=1)
env = RewardWrapper(env)
# Wrap the environment with RecordVideo to record videos
video_folder = f"./videos_{timestamp}/"
render_game_every_n = 10
env = RecordVideo(env, video_folder=video_folder, episode_trigger=lambda episode_id: episode_id % render_game_every_n == 0)

# %%
# Create the policy
policy = model.Policy(env)

# %%
policy.run_episode(10)
