# %%
from model import Policy
from gym_env import RewardWrapper, ChannelFirstWrapper, NormalizeWrapper

from gymnasium.wrappers import RecordVideo
import datetime
import gymnasium as gym
# import multi_agent_ale_py
import ale_py

# %%
# Get the current timestamp
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# Create the Gymnasium environment
env = gym.make("ALE/Surround-v5", render_mode="rgb_array", mode=2, difficulty=1)
env = RewardWrapper(env)
env = ChannelFirstWrapper(env)
env = NormalizeWrapper(env) 
# Wrap the environment with RecordVideo to record videos
video_folder = f"./videos_{timestamp}/"
render_game_every_n = 10
env = RecordVideo(env, video_folder=video_folder, episode_trigger=lambda episode_id: episode_id % render_game_every_n == 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6 env = RewardWrapper(env)
#       7 env = ChannelFirstWrapper(env)
# ----> 8 env = NormalizeWrapper(env)
#       9 # Wrap the environment with RecordVideo to record videos
#      10 video_folder = f"./videos_{timestamp}/"
#
# NameError: name 'NormalizeWrapper' is not defined

# %%
# Create the policy
policy = Policy(env)
# Out:
# (210, 160, 3)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Create the policy
# ----> 2 policy = Policy(env)
#
# File ~/ACM_AI/SlitheRL/model.py:95, in Policy.__init__(self, env)
#      92 self.state_space = env.observation_space.shape
#      93 self.action_space = env.action_space.n
# ---> 95 self.feature_extractor = ResNetCNNExtractor(env)
#      96 self.policy = nn.Sequential(
#      97     nn.Linear(512, 128),
#      98     nn.ReLU(),
#      99     nn.Linear(128, self.action_space)
#     100 )
#     102 # Episode policy and reward history
#
# File ~/ACM_AI/SlitheRL/model.py:61, in ResNetCNNExtractor.__init__(self, env, features_dim)
#      59 # Compute shape by doing one forward pass
#      60 with torch.no_grad():
# ---> 61     print(self.flatten(self._forward_conv(torch.as_tensor(env.observation_space.sample()[None]).float())).shape)
#      62     n_flatten = self.flatten(self._forward_conv(torch.as_tensor(env.observation_space.sample()[None]).float())).shape[1]
#      64 self.linear = nn.Sequential(
#      65     nn.Linear(n_flatten, features_dim),
#      66     nn.ReLU()
#      67 )
#
# File ~/ACM_AI/SlitheRL/model.py:76, in ResNetCNNExtractor._forward_conv(self, x)
#      75 def _forward_conv(self, x):
# ---> 76     x = self.relu(self.bn1(self.conv1(x)))
#      77     x = self.layer1(x)
#      78     x = self.layer2(x)
#
# File ~/miniconda3/envs/slitherl/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/slitherl/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/slitherl/lib/python3.10/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/slitherl/lib/python3.10/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# RuntimeError: Given groups=1, weight of size [32, 3, 8, 8], expected input[1, 210, 160, 3] to have 3 channels, but got 210 channels instead

# %%
policy.run_episode(10)
